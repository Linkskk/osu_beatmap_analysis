# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.impute import SimpleImputer

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import keras

# %%
# %matplotlib inline

# %% [markdown]
# Loading the data

# %%
df = pd.read_csv("/content/metadata.csv")
df
# Out:
#                               Unnamed: 0  split  \
# 0       0000e4db9a35c1e567265d350c299569  train
# 1       00010f0eb02ee131aacac54bf72d5444  train
# 2       0001599a2547ff2113753923d9bb93f6  train
# 3       0002d54f1de47dbcd242ff3dd2e24274  valid
# 4       00034f3ca36bb76bb69e30c276726221  valid
# ...                                  ...    ...
# 107972  fffaaa19b829e9468fb262a43a1d35ed  valid
# 107973  fffb035752ca9dc399e5bb29becce59d  train
# 107974  fffdb4b5f8979c30b4c2775a36fe16a4   test
# 107975  ffff066a8aff02ef0c512f6d505e5f70  train
# 107976  fffff187d2ae2e86b90db7959ca16869  train
#
#                               audio_hash  beatmapset_id  beatmap_id  approved  \
# 0       b06a550c393d8a72441932508595bf4e          35233      120019         1
# 1       5bea04ca275826768fa4f8411822c388         830266     1739583         1
# 2       f1a3190966c37d8aa83fe540f12e43f2         881569     1844646         1
# 3       d8702cabd065196cead6742827050265         658811     1395349         1
# 4       19f71684a3c9a710594c7e927345c11d          56940      175250         1
# ...                                  ...            ...         ...       ...
# 107972  b971c4d39da4d66622ee87ebd8d72757         529724     1123159         1
# 107973  60ecfb5ff249d6c403e0c5285392cb36         847800     1772965         1
# 107974  6ecf260446def434363f30ca013988a2        1236029     2569441         1
# 107975  22665e687f646516a3f7821f528bb3f3         859022     1795143         1
# 107976  590d3e61f27ee0aae81238756aabef79         434391      936797         1
#
#         total_length  hit_length  \
# 0                102          88
# 1                221         215
# 2                 96          95
# 3                380         368
# 4                 87          81
# ...              ...         ...
# 107972           209         178
# 107973           114         113
# 107974           165         163
# 107975            87          87
# 107976           119          86
#
#                                                   version  \
# 0                                             Zelos' Hard
# 1                                             Zero Vector
# 2                                           Poii's Futsuu
# 3                                           Virtual Beach
# 4                                          Quilt's Insane
# ...                                                   ...
# 107972                                     Mikii's Insane
# 107973                                                Cup
# 107974                                   Blacken's Purify
# 107975  I would really prefer if you would be quiet fe...
# 107976                                     apple's Insane
#
#                                 file_md5  ...  video  download_unavailable  \
# 0       0000e4db9a35c1e567265d350c299569  ...      0                     0
# 1       00010f0eb02ee131aacac54bf72d5444  ...      0                     0
# 2       0001599a2547ff2113753923d9bb93f6  ...      0                     0
# 3       0002d54f1de47dbcd242ff3dd2e24274  ...      0                     0
# 4       00034f3ca36bb76bb69e30c276726221  ...      1                     0
# ...                                  ...  ...    ...                   ...
# 107972  fffaaa19b829e9468fb262a43a1d35ed  ...      0                     0
# 107973  fffb035752ca9dc399e5bb29becce59d  ...      0                     0
# 107974  fffdb4b5f8979c30b4c2775a36fe16a4  ...      0                     0
# 107975  ffff066a8aff02ef0c512f6d505e5f70  ...      0                     0
# 107976  fffff187d2ae2e86b90db7959ca16869  ...      0                     0
#
#         audio_unavailable  playcount  passcount         packs  max_combo  \
# 0                       0      40780      16453  R38,R39,S203      297.0
# 1                       0      37233       4581          S757      939.0
# 2                       0       1036        530          ST50      194.0
# 3                       0      36207       3213          S624     1394.0
# 4                       0     622464      86133          S310      403.0
# ...                   ...        ...        ...           ...        ...
# 107972                  0     289473      77736          S524      976.0
# 107973                  0       3735       1260          SC18      328.0
# 107974                  0       1774        225         ST127     1317.0
# 107975                  0      73521      14463          S759      371.0
# 107976                  0     496874     102970          S506      521.0
#
#         diff_aim diff_speed difficultyrating
# 0        1.38127    1.27099          2.70740
# 1        2.49147    2.39868          4.93655
# 2            NaN        NaN          1.93105
# 3        1.85486    1.65950          3.61204
# 4        2.01999    1.84677          3.95337
# ...          ...        ...              ...
# 107972   2.31537    2.05292          4.49952
# 107973   1.62398        NaN          1.62398
# 107974       NaN        NaN          6.26060
# 107975   2.31619    1.88854          4.41856
# 107976   2.19528    1.96781          4.27682
#
# [107977 rows x 45 columns]

# %%
df[["version", "diff_overall", "diff_approach", "title"]]
# Out:
#                                                   version  diff_overall  \
# 0                                             Zelos' Hard           5.0
# 1                                             Zero Vector           8.0
# 3                                           Virtual Beach           7.0
# 4                                          Quilt's Insane           7.0
# 5                                                   Extra           8.4
# ...                                                   ...           ...
# 107970                                               Easy           2.0
# 107971                                               Easy           2.0
# 107972                                     Mikii's Insane           7.0
# 107975  I would really prefer if you would be quiet fe...           7.4
# 107976                                     apple's Insane           7.0
#
#         diff_approach                                title
# 0                 7.0          Tung, The Icelandic Lesbian
# 1                 8.0                   Zi You Sheng Guang
# 3                 7.0                ECCO to Okan Daibingu
# 4                 8.0  Little Busters! -TV animation ver.-
# 5                 9.2                             Angelica
# ...               ...                                  ...
# 107970            3.0              Fanshi 3 Kami Goranshin
# 107971            3.0                   Lonely Hearts Club
# 107972            9.0                              Juubaku
# 107975            8.3              Donglin Forest (Cursed)
# 107976            9.0      Mad World (Station Earth Remix)
#
# [81593 rows x 4 columns]

# %%
df.dropna(subset=["difficultyrating", "diff_aim", "diff_speed"], inplace=True)

# %% [markdown]
# Cleaning the data

# %%
df.drop_duplicates(inplace=True)

# %%
deleted_columns = ["Unnamed: 0", "audio_hash", "beatmapset_id", "beatmap_id", 'audio_unavailable',
                   "file_md5", "artist_unicode", "title_unicode", "packs", "submit_date",'packs',
                   "approved_date", "last_update", 'artist_unicode', 'title_unicode', 'creator_id', 'download_unavailable', ]

df.drop(columns= deleted_columns, axis=1, inplace=True)
df
# Out:
#         split  approved  total_length  hit_length  \
# 0       train         1           102          88
# 1       train         1           221         215
# 3       valid         1           380         368
# 4       valid         1            87          81
# 5       train         1           127          89
# ...       ...       ...           ...         ...
# 107970  train         1           179         164
# 107971   test         1           159         133
# 107972  valid         1           209         178
# 107975  train         1            87          87
# 107976  train         1           119          86
#
#                                                   version  diff_size  \
# 0                                             Zelos' Hard        4.0
# 1                                             Zero Vector        5.0
# 3                                           Virtual Beach        3.0
# 4                                          Quilt's Insane        4.0
# 5                                                   Extra        4.0
# ...                                                   ...        ...
# 107970                                               Easy        3.0
# 107971                                               Easy        2.6
# 107972                                     Mikii's Insane        4.0
# 107975  I would really prefer if you would be quiet fe...        4.2
# 107976                                     apple's Insane        4.0
#
#         diff_overall  diff_approach  diff_drain  mode  ...  favourite_count  \
# 0                5.0            7.0         5.0     0  ...               66
# 1                8.0            8.0         5.0     0  ...               71
# 3                7.0            7.0         6.0     0  ...               97
# 4                7.0            8.0         7.0     0  ...              161
# 5                8.4            9.2         5.5     0  ...              165
# ...              ...            ...         ...   ...  ...              ...
# 107970           2.0            3.0         2.0     0  ...               76
# 107971           2.0            3.0         2.0     0  ...              121
# 107972           7.0            9.0         6.0     0  ...              929
# 107975           7.4            8.3         6.5     0  ...               64
# 107976           7.0            9.0         6.0     0  ...              533
#
#          rating  storyboard video playcount passcount  max_combo  diff_aim  \
# 0       9.18201           1     0     40780     16453      297.0  1.381270
# 1       8.37821           0     0     37233      4581      939.0  2.491470
# 3       9.11765           0     0     36207      3213     1394.0  1.854860
# 4       9.37756           0     1    622464     86133      403.0  2.019990
# 5       9.41860           0     0     30574      4671      730.0  2.864170
# ...         ...         ...   ...       ...       ...        ...       ...
# 107970  9.48749           0     0     21618     10885      314.0  0.750037
# 107971  8.94771           0     0     16867      7285      394.0  1.007870
# 107972  9.52977           0     0    289473     77736      976.0  2.315370
# 107975  9.00329           0     0     73521     14463      371.0  2.316190
# 107976  9.42497           0     0    496874    102970      521.0  2.195280
#
#        diff_speed  difficultyrating
# 0        1.270990           2.70740
# 1        2.398680           4.93655
# 3        1.659500           3.61204
# 4        1.846770           3.95337
# 5        2.686040           5.63927
# ...           ...               ...
# 107970   0.704831           1.47747
# 107971   0.876717           1.95016
# 107972   2.052920           4.49952
# 107975   1.888540           4.41856
# 107976   1.967810           4.27682
#
# [81593 rows x 31 columns]

# %%
ax = plt.figure(figsize=(15, 10))
corr_data = df.corr(numeric_only=True)
corr_data = corr_data.fillna(0)
sns.clustermap(corr_data, cmap="magma")

# %%
language_type = {0: "any", 1: "unspecified", 2: "english", 3: "japanese", 4: "chinese", 5: "instrumental", 6: "korean",
                 7: "french", 8: "german", 9: "swedish", 10: "spanish", 11: "italian", 12: "russian", 13: "polish", 14: "other"}
genre_type = {0: "any", 1: "unspecified", 2: "video game", 3: "anime", 4: "rock", 5: "pop", 6: "other",
                 7: "novelty", 9: "hip hop", 10: "electronic", 11: "metal", 12: "classical", 13: "folk", 14: "jazz"}


df['language_id'] = df['language_id'].map(language_type)
df['genre_id'] = df['genre_id'].map(genre_type)

# %% [markdown]
# Data visualisation

# %%
plt.figure(figsize=(8, 8))
data = df.groupby(["title"]).playcount.mean().sort_values(ascending=False)[:20]
sns.barplot(x=data, y=data.index, palette="magma")
plt.xlabel("playcount")
plt.ylabel("artist name")
plt.title("Top 20 beatmaps by playcount")
# Out:
# Text(0.5, 1.0, 'Top 20 beatmaps by playcount')

# %%
plt.figure(figsize=(8, 8))
data = df.groupby(["title"]).difficultyrating.mean().sort_values(ascending=False)[:20]
sns.barplot(x=data, y=data.index, palette="magma")
plt.xlabel("difficulty")
plt.ylabel("artist name")
plt.title("Top 20 beatmaps by difficulty")
# Out:
# Text(0.5, 1.0, 'Top 20 beatmaps by difficulty')

# %%
# First subplot
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 10))
data = df.groupby(["title"]).difficultyrating.mean().sort_values(ascending=False)[:20]
sns.barplot(x=data, y=data.index, palette="inferno", ax=axes[0])
axes[0].set_xlabel("Average difficulty")
axes[0].set_title("Top 20 Beatmaps by difficulty")

# Second subplot
data = df.groupby(["artist"]).difficultyrating.mean().sort_values(ascending=False)[:20]
sns.barplot(x=data, y=data.index, palette="inferno", ax=axes[1])
axes[1].set_xlabel("Average difficulty")
axes[1].set_title("Top 20 Artists by difficulty")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
difficulty_columns = ["mode", "split", "count_normal", 'count_slider', 'total_length',
                      'hit_length', 'max_combo', 'diff_approach', "diff_overall", "diff_aim",
                      "diff_speed", "difficultyrating", "diff_size", "diff_drain", "bpm"]
data = df[difficulty_columns]

# %%
data
# Out:
#         mode  split  count_normal  count_slider  total_length  hit_length  \
# 0          0  train            76            85           102          88
# 1          0  train           939             0           221         215
# 3          0  valid           354           439           380         368
# 4          0  valid           171           100            87          81
# 5          0  train           351           159           127          89
# ...      ...    ...           ...           ...           ...         ...
# 107970     0  train            59            85           179         164
# 107971     0   test            72           108           159         133
# 107972     0  valid           246           328           209         178
# 107975     0  train           189            85            87          87
# 107976     0  train           134           160           119          86
#
#         max_combo  diff_approach  diff_overall  diff_aim  diff_speed  \
# 0           297.0            7.0           5.0  1.381270    1.270990
# 1           939.0            8.0           8.0  2.491470    2.398680
# 3          1394.0            7.0           7.0  1.854860    1.659500
# 4           403.0            8.0           7.0  2.019990    1.846770
# 5           730.0            9.2           8.4  2.864170    2.686040
# ...           ...            ...           ...       ...         ...
# 107970      314.0            3.0           2.0  0.750037    0.704831
# 107971      394.0            3.0           2.0  1.007870    0.876717
# 107972      976.0            9.0           7.0  2.315370    2.052920
# 107975      371.0            8.3           7.4  2.316190    1.888540
# 107976      521.0            9.0           7.0  2.195280    1.967810
#
#         difficultyrating  diff_size  diff_drain     bpm
# 0                2.70740        4.0         5.0  160.00
# 1                4.93655        5.0         5.0  140.00
# 3                3.61204        3.0         6.0   81.65
# 4                3.95337        4.0         7.0  151.00
# 5                5.63927        4.0         5.5  190.00
# ...                  ...        ...         ...     ...
# 107970           1.47747        3.0         2.0  151.00
# 107971           1.95016        2.6         2.0  200.00
# 107972           4.49952        4.0         6.0  190.00
# 107975           4.41856        4.2         6.5  155.75
# 107976           4.27682        4.0         6.0  174.00
#
# [81593 rows x 15 columns]

# %%
train_data = data[data.split == "train"].drop(columns = ["split"])
valid_data = data[data.split == "valid"].drop(columns = ["split"])
test_data = data[data.split == "test"].drop(columns = ["split"])

# %%
diff_aim_train = train_data.pop("diff_aim")
diff_speed_train = train_data.pop("diff_speed")
overall_diff_train = train_data.pop("difficultyrating")

diff_aim_valid = valid_data.pop("diff_aim")
diff_speed_valid = valid_data.pop("diff_speed")
overall_diff_valid = valid_data.pop("difficultyrating")

diff_aim_test = test_data.pop("diff_aim")
diff_speed_test = test_data.pop("diff_speed")
overall_diff_test = test_data.pop("difficultyrating")

# %%
overall_diff_train
# Out:
# 0         2.70740
# 1         4.93655
# 5         5.63927
# 6         2.02578
# 7         2.73521
#            ...
# 107967    3.29049
# 107968    4.37089
# 107970    1.47747
# 107975    4.41856
# 107976    4.27682
# Name: difficultyrating, Length: 65505, dtype: float64

# %%
difficulty_imputer = SimpleImputer(strategy="median")
train_data = difficulty_imputer.fit_transform(train_data)
valid_data = difficulty_imputer.transform(valid_data)

difficulty_scaler = StandardScaler()
train_data = difficulty_scaler.fit_transform(train_data)
valid_data = difficulty_scaler.transform(valid_data)

# %% [markdown]
# Creating the model

# %%
input = keras.Input(shape=(11, ))
x = layers.Dense(units=64, activation="relu")(input)
x = layers.Dense(units=64, activation="relu")(x)
x = layers.Dense(units=64, activation="relu")(x)
x = layers.Dense(units=64, activation="relu")(x)
aim_output = layers.Dense(1)(x)
speed_output = layers.Dense(1)(x)
diff_output = layers.Dense(1)(x)

model = keras.Model(inputs = input, outputs=[aim_output, speed_output, diff_output])

model.compile(optimizer="rmsprop",
              loss="mse",
              metrics="mae")

early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True
)

model.fit(
    train_data,
    [diff_aim_train, diff_speed_train, overall_diff_train],
    epochs=100,
    batch_size=64,
    validation_data=[valid_data,
                     [diff_aim_valid, diff_speed_valid, overall_diff_valid]],
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 1024/1024 [==============================] - 4s 3ms/step - loss: 0.4032 - dense_46_loss: 0.0758 - dense_47_loss: 0.0654 - dense_48_loss: 0.2620 - dense_46_mae: 0.1795 - dense_47_mae: 0.1598 - dense_48_mae: 0.3218 - val_loss: 0.2217 - val_dense_46_loss: 0.0487 - val_dense_47_loss: 0.0309 - val_dense_48_loss: 0.1421 - val_dense_46_mae: 0.1590 - val_dense_47_mae: 0.1258 - val_dense_48_mae: 0.2730
# Epoch 2/100
# 1024/1024 [==============================] - 3s 2ms/step - loss: 0.1582 - dense_46_loss: 0.0352 - dense_47_loss: 0.0226 - dense_48_loss: 0.1004 - dense_46_mae: 0.1380 - dense_47_mae: 0.1105 - dense_48_mae: 0.2342 - val_loss: 0.1349 - val_dense_46_loss: 0.0311 - val_dense_47_loss: 0.0176 - val_dense_48_loss: 0.0862 - val_dense_46_mae: 0.1291 - val_dense_47_mae: 0.0978 - val_dense_48_mae: 0.2161
# Epoch 3/100
# 1024/1024 [==============================] - 2s 2ms/step - loss: 0.1429 - dense_46_loss: 0.0322 - dense_47_loss: 0.0202 - dense_48_loss: 0.0905 - dense_46_mae: 0.1319 - dense_47_mae: 0.1038 - dense_48_mae: 0.2217 - val_loss: 0.1372 - val_dense_46_loss: 0.0321 - val_dense_47_loss: 0.0173 - val_dense_48_loss: 0.0879 - val_dense_46_mae: 0.1300 - val_dense_47_mae: 0.0935 - val_dense_48_mae: 0.2142
# Epoch 4/100
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.1373 - dense_46_loss: 0.0312 - dense_47_loss: 0.0191 - dense_48_loss: 0.0869 - dense_46_mae: 0.1295 - dense_47_mae: 0.1003 - dense_48_mae: 0.2166 - val_loss: 0.1336 - val_dense_46_loss: 0.0313 - val_dense_47_loss: 0.0171 - val_dense_48_loss: 0.0852 - val_dense_46_mae: 0.1301 - val_dense_47_mae: 0.0964 - val_dense_48_mae: 0.2143
# Epoch 5/100
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.1308 - dense_46_loss: 0.0299 - dense_47_loss: 0.0182 - dense_48_loss: 0.0827 - dense_46_mae: 0.1268 - dense_47_mae: 0.0977 - dense_48_mae: 0.2112 - val_loss: 0.2189 - val_dense_46_loss: 0.0444 - val_dense_47_loss: 0.0347 - val_dense_48_loss: 0.1398 - val_dense_46_mae: 0.1515 - val_dense_47_mae: 0.1364 - val_dense_48_mae: 0.2698
# Epoch 6/100
# 1024/1024 [==============================] - 2s 2ms/step - loss: 0.1265 - dense_46_loss: 0.0291 - dense_47_loss: 0.0175 - dense_48_loss: 0.0799 - dense_46_mae: 0.1250 - dense_47_mae: 0.0961 - dense_48_mae: 0.2082 - val_loss: 0.1512 - val_dense_46_loss: 0.0329 - val_dense_47_loss: 0.0210 - val_dense_48_loss: 0.0973 - val_dense_46_mae: 0.1389 - val_dense_47_mae: 0.1140 - val_dense_48_mae: 0.2439
# Epoch 7/100
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.1239 - dense_46_loss: 0.0285 - dense_47_loss: 0.0170 - dense_48_loss: 0.0783 - dense_46_mae: 0.1239 - dense_47_mae: 0.0947 - dense_48_mae: 0.2060 - val_loss: 0.1330 - val_dense_46_loss: 0.0305 - val_dense_47_loss: 0.0160 - val_dense_48_loss: 0.0865 - val_dense_46_mae: 0.1237 - val_dense_47_mae: 0.0882 - val_dense_48_mae: 0.2072
# Epoch 8/100
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.1210 - dense_46_loss: 0.0279 - dense_47_loss: 0.0166 - dense_48_loss: 0.0764 - dense_46_mae: 0.1226 - dense_47_mae: 0.0935 - dense_48_mae: 0.2034 - val_loss: 0.1204 - val_dense_46_loss: 0.0276 - val_dense_47_loss: 0.0159 - val_dense_48_loss: 0.0769 - val_dense_46_mae: 0.1204 - val_dense_47_mae: 0.0894 - val_dense_48_mae: 0.2009
# Epoch 9/100
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.1203 - dense_46_loss: 0.0279 - dense_47_loss: 0.0164 - dense_48_loss: 0.0760 - dense_46_mae: 0.1221 - dense_47_mae: 0.0925 - dense_48_mae: 0.2024 - val_loss: 0.1158 - val_dense_46_loss: 0.0269 - val_dense_47_loss: 0.0150 - val_dense_48_loss: 0.0739 - val_dense_46_mae: 0.1186 - val_dense_47_mae: 0.0876 - val_dense_48_mae: 0.1966
# Epoch 10/100
# 1024/1024 [==============================] - 2s 2ms/step - loss: 0.1175 - dense_46_loss: 0.0273 - dense_47_loss: 0.0161 - dense_48_loss: 0.0742 - dense_46_mae: 0.1210 - dense_47_mae: 0.0916 - dense_48_mae: 0.2003 - val_loss: 0.1446 - val_dense_46_loss: 0.0323 - val_dense_47_loss: 0.0199 - val_dense_48_loss: 0.0925 - val_dense_46_mae: 0.1336 - val_dense_47_mae: 0.1067 - val_dense_48_mae: 0.2297
# Epoch 11/100
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.1170 - dense_46_loss: 0.0271 - dense_47_loss: 0.0160 - dense_48_loss: 0.0739 - dense_46_mae: 0.1207 - dense_47_mae: 0.0914 - dense_48_mae: 0.1998 - val_loss: 0.1616 - val_dense_46_loss: 0.0380 - val_dense_47_loss: 0.0185 - val_dense_48_loss: 0.1051 - val_dense_46_mae: 0.1389 - val_dense_47_mae: 0.0944 - val_dense_48_mae: 0.2307
# Epoch 12/100
# 1024/1024 [==============================] - 3s 2ms/step - loss: 0.1153 - dense_46_loss: 0.0268 - dense_47_loss: 0.0157 - dense_48_loss: 0.0728 - dense_46_mae: 0.1199 - dense_47_mae: 0.0905 - dense_48_mae: 0.1983 - val_loss: 0.1934 - val_dense_46_loss: 0.0441 - val_dense_47_loss: 0.0222 - val_dense_48_loss: 0.1271 - val_dense_46_mae: 0.1505 - val_dense_47_mae: 0.1041 - val_dense_48_mae: 0.2558
# Epoch 13/100
# 1024/1024 [==============================] - 3s 2ms/step - loss: 0.1149 - dense_46_loss: 0.0268 - dense_47_loss: 0.0155 - dense_48_loss: 0.0726 - dense_46_mae: 0.1198 - dense_47_mae: 0.0898 - dense_48_mae: 0.1977 - val_loss: 0.1131 - val_dense_46_loss: 0.0266 - val_dense_47_loss: 0.0147 - val_dense_48_loss: 0.0717 - val_dense_46_mae: 0.1175 - val_dense_47_mae: 0.0882 - val_dense_48_mae: 0.1946
# Epoch 14/100
# 1024/1024 [==============================] - 2s 2ms/step - loss: 0.1134 - dense_46_loss: 0.0264 - dense_47_loss: 0.0154 - dense_48_loss: 0.0715 - dense_46_mae: 0.1190 - dense_47_mae: 0.0897 - dense_48_mae: 0.1966 - val_loss: 0.1285 - val_dense_46_loss: 0.0285 - val_dense_47_loss: 0.0186 - val_dense_48_loss: 0.0813 - val_dense_46_mae: 0.1223 - val_dense_47_mae: 0.0981 - val_dense_48_mae: 0.2066
# Epoch 15/100
# 1024/1024 [==============================] - 2s 2ms/step - loss: 0.1121 - dense_46_loss: 0.0261 - dense_47_loss: 0.0152 - dense_48_loss: 0.0707 - dense_46_mae: 0.1184 - dense_47_mae: 0.0891 - dense_48_mae: 0.1955 - val_loss: 0.1131 - val_dense_46_loss: 0.0261 - val_dense_47_loss: 0.0150 - val_dense_48_loss: 0.0720 - val_dense_46_mae: 0.1170 - val_dense_47_mae: 0.0877 - val_dense_48_mae: 0.1944
# Epoch 16/100
# 1024/1024 [==============================] - 3s 2ms/step - loss: 0.1111 - dense_46_loss: 0.0259 - dense_47_loss: 0.0151 - dense_48_loss: 0.0701 - dense_46_mae: 0.1181 - dense_47_mae: 0.0886 - dense_48_mae: 0.1946 - val_loss: 0.1210 - val_dense_46_loss: 0.0268 - val_dense_47_loss: 0.0182 - val_dense_48_loss: 0.0760 - val_dense_46_mae: 0.1178 - val_dense_47_mae: 0.0950 - val_dense_48_mae: 0.1975
# Epoch 17/100
# 1024/1024 [==============================] - 2s 2ms/step - loss: 0.1108 - dense_46_loss: 0.0259 - dense_47_loss: 0.0150 - dense_48_loss: 0.0699 - dense_46_mae: 0.1178 - dense_47_mae: 0.0884 - dense_48_mae: 0.1941 - val_loss: 0.1152 - val_dense_46_loss: 0.0265 - val_dense_47_loss: 0.0151 - val_dense_48_loss: 0.0737 - val_dense_46_mae: 0.1183 - val_dense_47_mae: 0.0876 - val_dense_48_mae: 0.1972
# Epoch 18/100
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.1097 - dense_46_loss: 0.0257 - dense_47_loss: 0.0149 - dense_48_loss: 0.0692 - dense_46_mae: 0.1173 - dense_47_mae: 0.0881 - dense_48_mae: 0.1933 - val_loss: 0.1389 - val_dense_46_loss: 0.0325 - val_dense_47_loss: 0.0174 - val_dense_48_loss: 0.0890 - val_dense_46_mae: 0.1284 - val_dense_47_mae: 0.0924 - val_dense_48_mae: 0.2116
# Epoch 19/100
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.1098 - dense_46_loss: 0.0257 - dense_47_loss: 0.0148 - dense_48_loss: 0.0693 - dense_46_mae: 0.1174 - dense_47_mae: 0.0878 - dense_48_mae: 0.1932 - val_loss: 0.1161 - val_dense_46_loss: 0.0264 - val_dense_47_loss: 0.0163 - val_dense_48_loss: 0.0734 - val_dense_46_mae: 0.1176 - val_dense_47_mae: 0.0919 - val_dense_48_mae: 0.1961
# Epoch 20/100
# 1024/1024 [==============================] - 2s 2ms/step - loss: 0.1092 - dense_46_loss: 0.0255 - dense_47_loss: 0.0148 - dense_48_loss: 0.0688 - dense_46_mae: 0.1172 - dense_47_mae: 0.0879 - dense_48_mae: 0.1930 - val_loss: 0.1153 - val_dense_46_loss: 0.0275 - val_dense_47_loss: 0.0147 - val_dense_48_loss: 0.0731 - val_dense_46_mae: 0.1191 - val_dense_47_mae: 0.0875 - val_dense_48_mae: 0.1944
# Epoch 21/100
# 1024/1024 [==============================] - 2s 2ms/step - loss: 0.1077 - dense_46_loss: 0.0253 - dense_47_loss: 0.0146 - dense_48_loss: 0.0678 - dense_46_mae: 0.1165 - dense_47_mae: 0.0873 - dense_48_mae: 0.1919 - val_loss: 0.1234 - val_dense_46_loss: 0.0282 - val_dense_47_loss: 0.0151 - val_dense_48_loss: 0.0801 - val_dense_46_mae: 0.1231 - val_dense_47_mae: 0.0897 - val_dense_48_mae: 0.2097
# Epoch 22/100
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.1070 - dense_46_loss: 0.0250 - dense_47_loss: 0.0146 - dense_48_loss: 0.0674 - dense_46_mae: 0.1163 - dense_47_mae: 0.0871 - dense_48_mae: 0.1913 - val_loss: 0.1338 - val_dense_46_loss: 0.0304 - val_dense_47_loss: 0.0185 - val_dense_48_loss: 0.0850 - val_dense_46_mae: 0.1253 - val_dense_47_mae: 0.0967 - val_dense_48_mae: 0.2092
# Epoch 23/100
# 1024/1024 [==============================] - 3s 3ms/step - loss: 0.1063 - dense_46_loss: 0.0249 - dense_47_loss: 0.0144 - dense_48_loss: 0.0669 - dense_46_mae: 0.1158 - dense_47_mae: 0.0868 - dense_48_mae: 0.1905 - val_loss: 0.1304 - val_dense_46_loss: 0.0298 - val_dense_47_loss: 0.0166 - val_dense_48_loss: 0.0841 - val_dense_46_mae: 0.1242 - val_dense_47_mae: 0.0911 - val_dense_48_mae: 0.2092

# %%
def preprocess_test_data(data):
  data = difficulty_imputer.transform(data)
  data = difficulty_scaler.transform(data)
  return data

test_data = preprocess_test_data(test_data)
results = model.evaluate(test_data, [diff_aim_test, diff_speed_test, overall_diff_test],  batch_size=64)
# Out:
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1074 - dense_46_loss: 0.0258 - dense_47_loss: 0.0136 - dense_48_loss: 0.0680 - dense_46_mae: 0.1172 - dense_47_mae: 0.0870 - dense_48_mae: 0.1924

# %%
def predict_rating(mode, count_normal, count_slider, total_length, hit_length, max_combo, diff_approach,
                   diff_overall, diff_size, diff_drain, bpm):
  beatmap_data = np.array([mode, count_normal, count_slider, total_length, hit_length, max_combo, diff_approach,
                   diff_overall, diff_size, diff_drain, bpm])
  beatmap_data = np.reshape(beatmap_data, (1, 11))
  beatmap_data = preprocess_test_data(beatmap_data)
  results = model.predict(beatmap_data, batch_size=1)
  return results

# %%
results = predict_rating(0, 896, 446, 258, 226, 1945, 9, 8, 4, 7, 222.22)
print(f"Speed difficulty: {results[0][0][0]}")
print(f"Aim difficulty: {results[1][0][0]}")
print(f"Beatmap star rating: {results[2][0][0]}")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Speed difficulty: 2.960747241973877
# Aim difficulty: 3.1080753803253174
# Beatmap star rating: 6.154012680053711
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
